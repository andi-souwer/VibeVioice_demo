# %% [markdown]
# # 下载VibeVoice系列模型
# 包括：VibeVoice-ASR-7B、VibeVoice-TTS-1.5B、VibeVoice-Realtime-0.5B
#
# 参考：
# - https://github.com/microsoft/VibeVoice
# - https://huggingface.co/collections/microsoft/vibevoice

# %%
from tqdm import tqdm
import huggingface_hub
from huggingface_hub import snapshot_download


huggingface_hub.login("xxxxx") # token 从 https://huggingface.co/settings/tokens 获取

import os
# 开启 Hugging Face 国内镜像，解决下载失败问题
os.environ["HF_ENDPOINT"] = "https://hf-mirror.com"

# %%
# VibeVoice-ASR-7B
snapshot_download(
  repo_id="microsoft/VibeVoice-ASR",
  local_dir="E:\\lenv\\llmmode\\localdown\\VibeVoice-ASR",
  # proxies={"https": "http://localhost:7890"},
#   proxies={"http": "socks5h://localhost:7898"},
  max_workers=8
)
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# 'E:\\lenv\\llmmode\\localdown\\VibeVoice-ASR'

# %%
# VibeVoice-TTS-1.5B
snapshot_download(
  repo_id="microsoft/VibeVoice-1.5B",
  local_dir="E:\\lenv\\llmmode\\localdown\\VibeVoice-1.5B",
  # proxies={"https": "http://localhost:7890"},
#   proxies={"http": "socks5h://localhost:7898"},
  max_workers=8
)
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# 'E:\\lenv\\llmmode\\localdown\\VibeVoice-1.5B'

# %%
# VibeVoice-Realtime-0.5B
snapshot_download(
    repo_id="microsoft/VibeVoice-Realtime-0.5B",
    local_dir="E:\\lenv\\llmmode\\localdown\\VibeVoice-Realtime-0.5B",
    # proxies={"https": "http://localhost:7890"},
    #   proxies={"http": "socks5h://localhost:7898"},
    max_workers=8
)
# Out:
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# 'E:\\lenv\\llmmode\\localdown\\VibeVoice-Realtime-0.5B'
